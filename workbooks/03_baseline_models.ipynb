# %% [markdown]
# ### 03 — Baseline + Improvement
# **W207 Final Project | Sentiment Classification of Restaurant Reviews**
#
# - **Baseline:** TF-IDF + Logistic Regression
# - **Improvement:** TF-IDF + Linear SVM and TF-IDF + XGBoost

# %%
# Imports

# %% [markdown]
# #### 1. TF-IDF features

# %%
### 1. TF-IDF features

# %% [markdown]
# #### 2. Baseline — Logistic Regression

# %%
### 2. Baseline with Logistic Regression

# %% [markdown]
# #### 3. Improvement — XGBoost

# %%
### 3. Improvement with XGBoost

# %% [markdown]
# #### 4. Model Selection and Evaluation

# %%
### 4. Compare model results, accuracy

# %% [markdown]
# #### 5. Error Analysis and Results

# %%
### 5. Preliminary results
