# %% [markdown]
# ## Exploratory Data Analysis: Reading CSV Files

# %% [markdown]
# ## Loading CSV Files from Google Drive
#
# First, we need to mount Google Drive to access its contents.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Now that Google Drive is mounted, let's define the path to your 'Exploratory Data Analysis' folder and list all `.csv` files within it.

# %%
import os
import pandas as pd

# Define the correct path to the user's Google Drive folder
drive_data_path = '/content/drive/MyDrive/207 Final Project/Exploratory Data Analysis/'

# Check if the directory exists
if not os.path.exists(drive_data_path):
    print(f"Error: The directory '{drive_data_path}' does not exist or is not accessible.")
    print("Please ensure the folder name is correct and Google Drive is mounted successfully.")
else:
    print(f"Files in '{drive_data_path}':")
    csv_files = [f for f in os.listdir(drive_data_path) if f.endswith('.csv')]
    if csv_files:
        for file_name in csv_files:
            print(file_name)
    else:
        print("No CSV files found in this directory.")
# Out:
# Files in '/content/drive/MyDrive/207 Final Project/Exploratory Data Analysis/':
# yelp_academic_dataset_business.csv
# yelp_academic_dataset_checkin.csv
# yelp_academic_dataset_tip.csv
# yelp_academic_dataset_user.csv
# yelp_academic_dataset_review.csv

# %% [markdown]
# Next, I will load each identified CSV file into a pandas DataFrame and display its first 5 rows.

# %%
import pandas as pd
import os

drive_data_path = '/content/drive/MyDrive/207 Final Project/Exploratory Data Analysis/'

# Filter for only the requested CSV files
requested_files = ['yelp_academic_dataset_business.csv', 'yelp_academic_dataset_review.csv']
csv_files = [f for f in os.listdir(drive_data_path) if f.endswith('.csv') and f in requested_files]

if csv_files:
    for file_name in csv_files:
        file_path = os.path.join(drive_data_path, file_name)
        print(f"\n--- Loading '{file_name}' ---")
        try:
            # Create a clean variable name for the DataFrame
            df_var_name = file_name.replace('.csv', '').replace(' ', '_').replace('-', '_').lower()
            globals()[f'{df_var_name}_df'] = pd.read_csv(file_path)
            print(f"DataFrame '{df_var_name}_df' loaded successfully. First 5 rows:")
            display(globals()[f'{df_var_name}_df'].head())
        except Exception as e:
            print(f"Error loading '{file_name}': {e}")
else:
    print("No requested CSV files found to load from this directory.")
# Out:
# --- Loading 'yelp_academic_dataset_business.csv' ---
# /tmp/ipykernel_59743/4040149245.py:17: DtypeWarning: Columns (11,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[f'{df_var_name}_df'] = pd.read_csv(file_path)
# DataFrame 'yelp_academic_dataset_business_df' loaded successfully. First 5 rows:
#   attributes.DietaryRestrictions hours.Friday attributes.Music  \
# 0                            NaN          NaN              NaN
# 1                            NaN    8:0-18:30              NaN
# 2                            NaN     8:0-23:0              NaN
# 3                            NaN     7:0-21:0              NaN
# 4                            NaN    12:0-22:0              NaN
#
#   attributes.BikeParking             business_id   latitude  \
# 0                    NaN  Pns2l4eNsfO8kk83dixA6A  34.426679
# 1                    NaN  mpf3x-BjTdTEA3yCZrAYPw  38.551126
# 2                   True  tUFrWirKiKi_TAnsVWINQQ  32.223236
# 3                   True  MTSW4McQd7CbVtyjqoe9mw  39.955505
# 4                   True  mWMc6_wTdE0EUBKIGXDVfA  40.338183
#
#   attributes.Alcohol                      name  \
# 0                NaN  Abby Rappoport, LAC, CMQ
# 1                NaN             The UPS Store
# 2                NaN                    Target
# 3            u'none'        St Honore Pastries
# 4                NaN  Perkiomen Valley Brewery
#
#    attributes.RestaurantsPriceRange2 attributes.HappyHour  ... review_count  \
# 0                                NaN                  NaN  ...            7
# 1                                NaN                  NaN  ...           15
# 2                                2.0                False  ...           22
# 3                                1.0                  NaN  ...           80
# 4                                NaN                  NaN  ...           13
#
#   attributes.DogsAllowed attributes.BusinessAcceptsBitcoin  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                  False                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#                           attributes.BusinessParking  hours.Monday  \
# 0                                                NaN           NaN
# 1                                                NaN       0:0-0:0
# 2  {'garage': False, 'street': False, 'validated'...      8:0-22:0
# 3  {'garage': False, 'street': True, 'validated':...      7:0-20:0
# 4  {'garage': None, 'street': None, 'validated': ...           NaN
#
#   attributes.Caters attributes.BYOB attributes.RestaurantsGoodForGroups state  \
# 0               NaN             NaN                                 NaN    CA
# 1               NaN             NaN                                 NaN    MO
# 2             False             NaN                                 NaN    AZ
# 3              True             NaN                                 NaN    PA
# 4             False             NaN                                 NaN    PA
#
#   hours.Sunday
# 0          NaN
# 1          NaN
# 2     8:0-22:0
# 3     7:0-21:0
# 4    12:0-18:0
#
# [5 rows x 60 columns]
# --- Loading 'yelp_academic_dataset_review.csv' ---
# DataFrame 'yelp_academic_dataset_review_df' loaded successfully. First 5 rows:
#    useful             business_id  \
# 0       0  XQfwVwDr-v0ZS3_CbbE5Xw
# 1       1  7ATYjTIgM3jUlt4UM3IypQ
# 2       0  YjUWPpI6HXG530lwP-fb2A
# 3       1  kxX2SOes4o-D3ZQBkiMRfA
# 4       1  e4Vwtrqf-wpJfwesgvdgxQ
#
#                                                 text               review_id  \
# 0  If you decide to eat here, just be aware it is...  KU_O5udG6zpxOg-VcAEodg
# 1  I've taken a lot of spin classes over the year...  BiTunyQ73aT9WBnpR9DZGw
# 2  Family diner. Had the buffet. Eclectic assortm...  saUsX_uimxRlCVr67Z4Jig
# 3  Wow!  Yummy, different,  delicious.   Our favo...  AqPFMleE6RsU23_auESxiA
# 4  Cute interior and owner (?) gave us tour of up...  Sx8TMOWLNuJBWer-0pcmoA
#
#    cool  funny                 date                 user_id  stars
# 0     0      0  2018-07-07 22:09:11  mh_-eMZ6K5RLWhZyISBhwA    3.0
# 1     1      0  2012-01-03 15:28:18  OyoGAe7OKpv6SyGZT5g77Q    5.0
# 2     0      0  2014-02-05 20:30:30  8g_iMtfSiwikVnbP2etR0A    3.0
# 3     1      0  2015-01-04 00:01:03  _7bHUi9Uuf5__HHc_Q8guQ    5.0
# 4     1      0  2017-01-14 20:54:15  bcjbaE6dDog4jkNY91ncLQ    4.0

# %% [markdown]
# ## Listing Column Names of Loaded DataFrames

# %%
print("\n--- Columns for yelp_academic_dataset_business_df ---")
if 'yelp_academic_dataset_business_df' in globals():
    for col in yelp_academic_dataset_business_df.columns:
        print(col)
else:
    print("yelp_academic_dataset_business_df not found.")

print("\n--- Columns for yelp_academic_dataset_review_df ---")
if 'yelp_academic_dataset_review_df' in globals():
    for col in yelp_academic_dataset_review_df.columns:
        print(col)
else:
    print("yelp_academic_dataset_review_df not found.")
# Out:
# --- Columns for yelp_academic_dataset_business_df ---
# attributes.DietaryRestrictions
# hours.Friday
# attributes.Music
# attributes.BikeParking
# business_id
# latitude
# attributes.Alcohol
# name
# attributes.RestaurantsPriceRange2
# attributes.HappyHour
# attributes.GoodForMeal
# attributes.RestaurantsCounterService
# attributes.HairSpecializesIn
# attributes.BestNights
# stars
# attributes.Smoking
# attributes.WiFi
# attributes.HasTV
# hours
# attributes.WheelchairAccessible
# is_open
# attributes.GoodForDancing
# attributes.AgesAllowed
# attributes.Corkage
# attributes.CoatCheck
# attributes.AcceptsInsurance
# attributes.RestaurantsDelivery
# attributes.RestaurantsTableService
# hours.Saturday
# hours.Wednesday
# categories
# attributes.RestaurantsTakeOut
# address
# attributes.NoiseLevel
# attributes.RestaurantsReservations
# postal_code
# attributes.DriveThru
# attributes.ByAppointmentOnly
# attributes.BusinessAcceptsCreditCards
# attributes
# attributes.BYOBCorkage
# attributes.OutdoorSeating
# attributes.GoodForKids
# city
# attributes.Open24Hours
# attributes.RestaurantsAttire
# hours.Thursday
# attributes.Ambience
# hours.Tuesday
# longitude
# review_count
# attributes.DogsAllowed
# attributes.BusinessAcceptsBitcoin
# attributes.BusinessParking
# hours.Monday
# attributes.Caters
# attributes.BYOB
# attributes.RestaurantsGoodForGroups
# state
# hours.Sunday
#
# --- Columns for yelp_academic_dataset_review_df ---
# useful
# business_id
# text
# review_id
# cool
# funny
# date
# user_id
# stars

# %%
# Keep only businesses in Santa Barbara, CA
sb_df = yelp_academic_dataset_business_df[
    (yelp_academic_dataset_business_df['city'] == 'Santa Barbara') &
    (yelp_academic_dataset_business_df['state'] == 'CA')
]

# Split the categories into individual categories and count them
sb_categories = (
    sb_df['categories']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
)

print(sb_categories.head(30))
# Out:
# categories
# Restaurants                  767
# Shopping                     685
# Food                         571
# Health & Medical             509
# Home Services                464
# Event Planning & Services    455
# Beauty & Spas                400
# Local Services               373
# Active Life                  264
# Hotels & Travel              258
# Nightlife                    255
# Bars                         221
# Arts & Entertainment         215
# Doctors                      214
# Automotive                   206
# Professional Services        205
# Fashion                      189
# Home & Garden                160
# American (New)               151
# Hair Salons                  132
# Fitness & Instruction        124
# Breakfast & Brunch           119
# Skin Care                    119
# Coffee & Tea                 119
# Mexican                      118
# Real Estate                  117
# Auto Repair                  109
# Beer                         104
# Wine & Spirits               104
# Sandwiches                   103
# Name: count, dtype: int64

# %%
restaurants_df = yelp_academic_dataset_business_df[
    (
        yelp_academic_dataset_business_df['categories'].str.contains('Restaurants|Food', na=False)
    ) &
    (
        yelp_academic_dataset_business_df['city'] == 'Santa Barbara'
    ) &
    (
        yelp_academic_dataset_business_df['state'] == 'CA'
    )
]

print(f"Number of restaurants: {len(restaurants_df)}")
display(restaurants_df.head())
# Out:
# Number of restaurants: 1082
#     attributes.DietaryRestrictions hours.Friday  \
# 85                             NaN     8:0-14:0
# 141                            NaN    11:0-21:0
# 431                            NaN   11:0-21:30
# 691                            NaN     6:0-17:0
# 946                            NaN    11:30-0:0
#
#                                       attributes.Music attributes.BikeParking  \
# 85                                                 NaN                   True
# 141  {u'dj': False, u'live': False, u'jukebox': Fal...                   True
# 431                                                NaN                    NaN
# 691                                                NaN                   True
# 946                                                 {}                   True
#
#                 business_id   latitude attributes.Alcohol  \
# 85   IDtLPgUrqorrpqSLdfMhZQ  34.414445            u'none'
# 141  SZU9c8V2GuREDN5KgyHFJw  34.408715    'beer_and_wine'
# 431  ifjluUv4VASwmFqEp8cWlQ  34.436236            u'none'
# 691  -kY_HDP7IMvGl-kBIZVU4A  34.418994                NaN
# 946  -ujBP1Dw0j1-Ffaz97-LXQ  34.415747    'beer_and_wine'
#
#                                 name  attributes.RestaurantsPriceRange2  \
# 85              Helena Avenue Bakery                                2.0
# 141  Santa Barbara Shellfish Company                                2.0
# 431                    Marty's Pizza                                2.0
# 691   Dune Coffee Roasters - Anacapa                                2.0
# 946                Lama Dog Tap Room                                2.0
#
#     attributes.HappyHour  ... review_count attributes.DogsAllowed  \
# 85                 False  ...          389                   True
# 141                False  ...         2404                    NaN
# 431                  NaN  ...           64                    NaN
# 691                  NaN  ...          320                    NaN
# 946                 True  ...          238                   True
#
#     attributes.BusinessAcceptsBitcoin  \
# 85                                NaN
# 141                             False
# 431                               NaN
# 691                               NaN
# 946                               NaN
#
#                             attributes.BusinessParking  hours.Monday  \
# 85   {'garage': False, 'street': True, 'validated':...       0:0-0:0
# 141  {'garage': False, 'street': False, 'validated'...       0:0-0:0
# 431  {'garage': None, 'street': None, 'validated': ...           NaN
# 691  {'garage': False, 'street': False, 'validated'...      6:0-17:0
# 946  {'garage': False, 'street': True, 'validated':...       0:0-0:0
#
#     attributes.Caters attributes.BYOB attributes.RestaurantsGoodForGroups  \
# 85               True             NaN                                True
# 141             False             NaN                               False
# 431               NaN             NaN                                True
# 691             False             NaN                                 NaN
# 946             False             NaN                                True
#
#     state hours.Sunday
# 85     CA     8:0-14:0
# 141    CA    11:0-21:0
# 431    CA   11:0-21:30
# 691    CA     7:0-17:0
# 946    CA   11:30-22:0
#
# [5 rows x 60 columns]

# %% [markdown]
# ## Merging Business and Review Data for Average Reviews

# %%
business_info_df = restaurants_df[
    [
        'business_id',
        'name',
        'city',
        'state',
        'categories',
        'is_open'
    ]
].copy()

# Select only necessary review columns
review_info_df = yelp_academic_dataset_review_df[
    [
        'business_id',
        'text',
        'stars',
        'useful',
        'funny',
        'cool',
        'date'
    ]
].copy()

# Merge the business and review datasets
merged_df = pd.merge(
    business_info_df,
    review_info_df,
    on='business_id',
    how='left'
)

print(f"Merged dataset shape: {merged_df.shape}")
display(merged_df.head())
# Out:
# Merged dataset shape: (183637, 12)
#               business_id                  name           city state  \
# 0  IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  Santa Barbara    CA
# 1  IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  Santa Barbara    CA
# 2  IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  Santa Barbara    CA
# 3  IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  Santa Barbara    CA
# 4  IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  Santa Barbara    CA
#
#                                           categories  is_open  \
# 0  Food, Restaurants, Salad, Coffee & Tea, Breakf...        1
# 1  Food, Restaurants, Salad, Coffee & Tea, Breakf...        1
# 2  Food, Restaurants, Salad, Coffee & Tea, Breakf...        1
# 3  Food, Restaurants, Salad, Coffee & Tea, Breakf...        1
# 4  Food, Restaurants, Salad, Coffee & Tea, Breakf...        1
#
#                                                 text  stars  useful  funny  \
# 0  What a great addition to the Funk Zone!  Grab ...    5.0       0      0
# 1  Possibly the best breakfast sandwich EVER.  On...    5.0       0      0
# 2  Pricey ( a ham and cheese croissant was $5.50)...    4.0       0      0
# 3  Are you kidding me? This is without a doubt so...    5.0       0      1
# 4  Super slow service, "salads" are not very good...    2.0       3      0
#
#    cool                 date
# 0     0  2016-10-13 22:50:47
# 1     0  2017-01-15 00:36:04
# 2     0  2018-07-17 00:20:41
# 3     1  2018-01-09 20:44:47
# 4     0  2017-02-09 19:09:31
